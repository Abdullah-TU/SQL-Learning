# %%
# %load_ext sql
# %sql sqlite://
# Out:
# 'Connected: @None'

# %%
# %%sql
#
# CREATE TABLE employee(enum INT,
#                       firstname varchar(50) NOT NULL,
#                       lastname varchar(50) NOT NULL,
#                       bdate DATE NOT NULL,
#                       locality varchar(50) NOT NULL,
#                       salary NUMERIC(8,2),
#                       phone VARCHAR(50) NOT NULL,
#                       deptnum INT NOT NULL,
#                       super_enum INT,
#                       PRIMARY KEY(enum),
#                       FOREIGN KEY(deptnum) REFERENCES department(dnum),
#                       FOREIGN KEY(super_enum ) REFERENCES employee(enum));
#
# INSERT INTO employee VALUES(88,'Jukka','Susi','1987-01-12','Tampere',50000.00, '044585663', 1, 89);
# INSERT INTO employee VALUES(33,'Ville','Viima','1990-03-01','Nokia',55000.00, '044585664',5,88);
# INSERT INTO employee VALUES(12,'Pekka','Puro','1993-01-18','Tampere',60000.00, '044585665',5,33);
# INSERT INTO employee VALUES(98,'Jenni','Joki','2000-04-21','Lempäälä',65000.00, '044585666',4,88);
# INSERT INTO employee VALUES(99,'Alli','Kivi','1987-01-12','Nokia',75000.00, '044585667',4,98);
#
# SELECT * from employee;
# Out:
#  * sqlite://
# Done.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# Done.
# [(88, 'Jukka', 'Susi', '1987-01-12', 'Tampere', 50000, '044585663', 1, 89),
#  (33, 'Ville', 'Viima', '1990-03-01', 'Nokia', 55000, '044585664', 5, 88),
#  (12, 'Pekka', 'Puro', '1993-01-18', 'Tampere', 60000, '044585665', 5, 33),
#  (98, 'Jenni', 'Joki', '2000-04-21', 'Lempäälä', 65000, '044585666', 4, 88),
#  (99, 'Alli', 'Kivi', '1987-01-12', 'Nokia', 75000, '044585667', 4, 98)]

# %%
# %%sql
#
# CREATE TABLE department(dnum INT,
#                         dname varchar(15) NOT NULL,
#                         PRIMARY KEY(dnum),
#                         UNIQUE(dname));
#
# INSERT INTO department VALUES(1,'Headquarters');
# INSERT INTO department VALUES(4,'Administration');
# INSERT INTO department VALUES(5,'Research');
#
# SELECT * from department;
# Out:
#  * sqlite://
# Done.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# Done.
# [(1, 'Headquarters'), (4, 'Administration'), (5, 'Research')]

# %%
# %%sql
#
# CREATE TABLE project(pnum INT,
#                      pname varchar(15) NOT NULL,
#                      PRIMARY KEY(pnum),
#                      UNIQUE(pname));
#
# INSERT INTO project VALUES(1,'Product X');
# INSERT INTO project VALUES(2,'Product Y');
# INSERT INTO project VALUES(3,'Product Z');
#
# SELECT * from project;
# Out:
#  * sqlite://
# Done.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# Done.
# [(1, 'Product X'), (2, 'Product Y'), (3, 'Product Z')]

# %%
# %%sql
#
# CREATE TABLE works_on(enum INT,
#                       pnum INT,
#                       hours NUMERIC(5,1),
#                       PRIMARY KEY(enum,pnum),
#                       FOREIGN KEY(enum) REFERENCES employee(enum),
#                       FOREIGN KEY(pnum) REFERENCES project(pnum));
#
# INSERT INTO works_on VALUES(12,1,32.5);
# INSERT INTO works_on VALUES(12,2,7.5);
# INSERT INTO works_on VALUES(33,2,10.0);
# INSERT INTO works_on VALUES(33,3,10.0);
# INSERT INTO works_on VALUES(99,3,30.0);
# INSERT INTO works_on VALUES(99,1,10.0);
# INSERT INTO works_on VALUES(98,2,15.0);
#
# SELECT * from works_on;
# Out:
#  * sqlite://
# Done.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# 1 rows affected.
# Done.
# [(12, 1, 32.5),
#  (12, 2, 7.5),
#  (33, 2, 10),
#  (33, 3, 10),
#  (99, 3, 30),
#  (99, 1, 10),
#  (98, 2, 15)]

# %%
# %%sql
#
# UPDATE department SET dname = 'Research center' WHERE dnum = 5;
#
# SELECT * from department;
# Out:
#  * sqlite://
# 1 rows affected.
# Done.
# [(1, 'Headquarters'), (4, 'Administration'), (5, 'Research center')]

# %%
# %%sql
#
# UPDATE employee SET deptnum =5, super_enum = 33 WHERE enum = 99;
# SELECT * from employee;
# Out:
#  * sqlite://
# 1 rows affected.
# Done.
# [(88, 'Jukka', 'Susi', '1987-01-12', 'Tampere', 50000, '044585663', 1, 89),
#  (33, 'Ville', 'Viima', '1990-03-01', 'Nokia', 55000, '044585664', 5, 88),
#  (12, 'Pekka', 'Puro', '1993-01-18', 'Tampere', 60000, '044585665', 5, 33),
#  (98, 'Jenni', 'Joki', '2000-04-21', 'Lempäälä', 65000, '044585666', 4, 88),
#  (99, 'Alli', 'Kivi', '1987-01-12', 'Nokia', 75000, '044585667', 5, 33)]

# %%
# %%sql
#
# UPDATE employee SET super_enum = NULL WHERE enum = 88;
# SELECT * from employee;
# Out:
#  * sqlite://
# 1 rows affected.
# Done.
# [(88, 'Jukka', 'Susi', '1987-01-12', 'Tampere', 50000, '044585663', 1, None),
#  (33, 'Ville', 'Viima', '1990-03-01', 'Nokia', 55000, '044585664', 5, 88),
#  (12, 'Pekka', 'Puro', '1993-01-18', 'Tampere', 60000, '044585665', 5, 33),
#  (98, 'Jenni', 'Joki', '2000-04-21', 'Lempäälä', 65000, '044585666', 4, 88),
#  (99, 'Alli', 'Kivi', '1987-01-12', 'Nokia', 75000, '044585667', 5, 33)]

# %%
# %%sql
#
# SELECT * from employee , department;
# Out:
#  * sqlite://
# Done.
# [(88, 'Jukka', 'Susi', '1987-01-12', 'Tampere', 50000, '044585663', 1, None, 1, 'Headquarters'),
#  (88, 'Jukka', 'Susi', '1987-01-12', 'Tampere', 50000, '044585663', 1, None, 4, 'Administration'),
#  (88, 'Jukka', 'Susi', '1987-01-12', 'Tampere', 50000, '044585663', 1, None, 5, 'Research center'),
#  (33, 'Ville', 'Viima', '1990-03-01', 'Nokia', 55000, '044585664', 5, 88, 1, 'Headquarters'),
#  (33, 'Ville', 'Viima', '1990-03-01', 'Nokia', 55000, '044585664', 5, 88, 4, 'Administration'),
#  (33, 'Ville', 'Viima', '1990-03-01', 'Nokia', 55000, '044585664', 5, 88, 5, 'Research center'),
#  (12, 'Pekka', 'Puro', '1993-01-18', 'Tampere', 60000, '044585665', 5, 33, 1, 'Headquarters'),
#  (12, 'Pekka', 'Puro', '1993-01-18', 'Tampere', 60000, '044585665', 5, 33, 4, 'Administration'),
#  (12, 'Pekka', 'Puro', '1993-01-18', 'Tampere', 60000, '044585665', 5, 33, 5, 'Research center'),
#  (98, 'Jenni', 'Joki', '2000-04-21', 'Lempäälä', 65000, '044585666', 4, 88, 1, 'Headquarters'),
#  (98, 'Jenni', 'Joki', '2000-04-21', 'Lempäälä', 65000, '044585666', 4, 88, 4, 'Administration'),
#  (98, 'Jenni', 'Joki', '2000-04-21', 'Lempäälä', 65000, '044585666', 4, 88, 5, 'Research center'),
#  (99, 'Alli', 'Kivi', '1987-01-12', 'Nokia', 75000, '044585667', 5, 33, 1, 'Headquarters'),
#  (99, 'Alli', 'Kivi', '1987-01-12', 'Nokia', 75000, '044585667', 5, 33, 4, 'Administration'),
#  (99, 'Alli', 'Kivi', '1987-01-12', 'Nokia', 75000, '044585667', 5, 33, 5, 'Research center')]

# %%
# %%sql
#
# SELECT lastname, firstname, dname
# From employee, department
# WHERE deptnum = dnum;
# Out:
#  * sqlite://
# Done.
# [('Susi', 'Jukka', 'Headquarters'),
#  ('Viima', 'Ville', 'Research center'),
#  ('Puro', 'Pekka', 'Research center'),
#  ('Joki', 'Jenni', 'Administration'),
#  ('Kivi', 'Alli', 'Research center')]

# %%
# %%sql
# SELECT employee.lastname, employee.firstname, department.dname
# FROM employee,department
# WHERE employee.deptnum = department.dnum;
# Out:
#  * sqlite://
# Done.
# [('Susi', 'Jukka', 'Headquarters'),
#  ('Viima', 'Ville', 'Research center'),
#  ('Puro', 'Pekka', 'Research center'),
#  ('Joki', 'Jenni', 'Administration'),
#  ('Kivi', 'Alli', 'Research center')]

# %%
# %%sql
# SELECT e.lastname,e.firstname, d.dname
# FROM employee AS e,department AS d
# WHERE e.deptnum = d.dnum;
# Out:
#  * sqlite://
# Done.
# [('Susi', 'Jukka', 'Headquarters'),
#  ('Viima', 'Ville', 'Research center'),
#  ('Puro', 'Pekka', 'Research center'),
#  ('Joki', 'Jenni', 'Administration'),
#  ('Kivi', 'Alli', 'Research center')]

# %%
# %%sql
# SELECT lastname,firstname, locality
# FROM employee ,department
# WHERE deptnum = dnum AND
# dname ='Administration';
# Out:
#  * sqlite://
# Done.
# [('Joki', 'Jenni', 'Lempäälä')]
